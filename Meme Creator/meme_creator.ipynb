# %%
import cv2
import matplotlib.pyplot as plt

# %%
# Import Image
img = cv2.imread('img/kappa.jpg')
plt.imshow(img)

# %%
# Make meme
meme_kappa = img.copy()
cv2.putText(meme_kappa, 'I LOOK GOOD', (10,30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,0), 2)
cv2.putText(meme_kappa, 'KAPPA', (60,220), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,0), 2)
plt.figure(figsize=(15,10))
plt.imshow(meme_kappa)
